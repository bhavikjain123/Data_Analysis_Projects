# %% [markdown]
# # Black Friday Dataset EDA and Feature Engineering
# ## Cleaning and preparing data for madel training

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.4

# %%
pip install --upgrade pandas
# Out:
# ...
#
# ...

# %%
# %matplotlib inline

# %%
#importing the dataset
df_train=pd.read_csv('blackFriday_train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
##  import the test data
df_test=pd.read_csv('blackFriday_test.csv')
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
print(type(df_train), type(df_test))
# Out:
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>

# %%
##MErge both train and test data
df = pd.concat([df_train, df_test], ignore_index=True)
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# %%
df[numeric_columns].corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023976        0.020276            0.004568
# Occupation         -0.023976    1.000000        0.023563           -0.008441
# Marital_Status      0.020276    0.023563        1.000000            0.019579
# Product_Category_1  0.004568   -0.008441        0.019579            1.000000
# Product_Category_2  0.002291   -0.000773        0.017131            0.540426
# Product_Category_3  0.002490    0.010450        0.018471            0.228299
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.002291            0.002490  0.004716
# Occupation                   -0.000773            0.010450  0.020833
# Marital_Status                0.017131            0.018471 -0.000463
# Product_Category_1            0.540426            0.228299 -0.343703
# ...

# %%
dark_palette = sns.dark_palette("navy", as_cmap=True)  # You can specify any dark color here

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df[numeric_columns].corr(), cmap=dark_palette, annot=True, fmt=".2f", linewidths=.5)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.drop(['User_ID'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
#Pre-Processing
#converting categorical columns in numerical
# get_dummies()(one-hot encoding): Its a common preprocessing step in ML when working with categorical data

pd.get_dummies(df['Gender'], prefix= 'Sex', prefix_sep='_')
# Out:
#         Sex_F  Sex_M
# 0        True  False
# 1        True  False
# 2        True  False
# 3        True  False
# 4       False   True
# ...       ...    ...
# 783662   True  False
# 783663   True  False
# 783664   True  False
# 783665   True  False
# 783666   True  False
#
# [783667 rows x 2 columns]

# %%
df['Gender']= df['Gender'].map({'F':0, 'M':1})
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
#Ordinal Encoding
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0    1          10             A
# 1       P00248942       0    1          10             A
# 2       P00087842       0    1          10             A
# 3       P00085442       0    1          10             A
# 4       P00285442       1    7          16             C
# ...           ...     ...  ...         ...           ...
# 783662  P00118942       0    3          15             B
# 783663  P00254642       0    3          15             B
# 783664  P00031842       0    3          15             B
# 783665  P00124742       0    5           1             C
# 783666  P00316642       0    5           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df['Age'].unique()
# Out:
# array([1, 7, 3, 5, 6, 4, 2], dtype=int64)

# %%
#fixing Categorical City_Category
df['City_Category']= df['City_Category'].astype(str)
df_city= pd.get_dummies(df['City_Category'])
df_city=df_city.astype(int)

# %%
df_city.head()
# Out:
#    A  B  C
# 0  1  0  0
# 1  1  0  0
# 2  1  0  0
# 3  1  0  0
# 4  0  0  1

# %%
df = pd.concat([df, df_city], axis=1)
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  A  B  C
# 0                 NaN                 NaN    8370.0  1  0  0
# 1                 6.0                14.0   15200.0  1  0  0
# 2                 NaN                 NaN    1422.0  1  0  0
# ...

# %%
df.drop(['City_Category'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# ...

# %%
#Missing values
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# A                                  0
# B                                  0
# C                                  0
# dtype: int64

# %%
#focus on replacing missing values
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: count, dtype: int64

# %%
df['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
#Replace the missing values with mode
df['Product_Category_2'] = df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     337299
# 14.0     78834
# 2.0      70498
# 16.0     61687
# 15.0     54114
# 5.0      37165
# 4.0      36705
# 6.0      23575
# 11.0     20230
# 17.0     19104
# 13.0     15054
# 9.0       8177
# 12.0      7801
# 10.0      4420
# 3.0       4123
# 18.0      4027
# 7.0        854
# Name: count, dtype: int64

# %%
#SAME for product_category_3
df['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df['Product_Category_3'].value_counts()
# Out:
# Product_Category_3
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: count, dtype: int64

# %%
df['Product_Category_3'].mode()[0]
# Out:
# 16.0

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
df['Product_Category_3'].value_counts()
# Out:
# Product_Category_3
# 16.0    592278
# 15.0     39968
# 14.0     26283
# 17.0     23818
# 5.0      23799
# 8.0      17861
# 9.0      16532
# 12.0     13115
# 13.0      7849
# 6.0       6888
# 18.0      6621
# 4.0       2691
# 11.0      2585
# 10.0      2501
# 3.0        878
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# ...

# %%
df.shape
# Out:
# (783667, 13)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4', '3', '1', '0'], dtype=object)

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                          4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  object
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  A                           783667 non-null  int32
#  11  B                           783667 non-null  int32
#  12  C                           783667 non-null  int32
# ...

# %%
df['Stay_In_Current_City_Years']= df['Stay_In_Current_City_Years'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int32
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  A                           783667 non-null  int32
#  11  B                           783667 non-null  int32
#  12  C                           783667 non-null  int32
# ...

# %%
#Visualisation
# sns.pairplot(df)

# %%
sns.barplot(x='Age',y= 'Purchase',hue='Gender',data=df,dodge=True)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# ### Observation:
# 1. Purchasing percentage of males over females are always high irrespective of age

# %%
#visualisation of purchase with occupation
sns.barplot(x='Occupation',y= 'Purchase',hue='Gender',data=df,dodge=True)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_1',y= 'Purchase',hue='Gender',data=df,dodge=True)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_2',y= 'Purchase',hue='Gender',data=df,dodge=True)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_3',y= 'Purchase',hue='Gender',data=df,dodge=True)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df[df['Purchase'].isnull()]
# Out:
#        Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 550068  P00128942       1    5           7                           2
# 550069  P00113442       1    3          17                           0
# 550070  P00288442       0    4           1                           4
# 550071  P00145342       0    4           1                           4
# 550072  P00053842       0    3           1                           1
# ...           ...     ...  ...         ...                         ...
# 783662  P00118942       0    3          15                           4
# 783663  P00254642       0    3          15                           4
# 783664  P00031842       0    3          15                           4
# 783665  P00124742       0    5           1                           4
# 783666  P00316642       0    5           0                           4
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# ...

# %%
#Feature scaling
df_test= df[df['Purchase'].isnull()]
df_test.head()
# Out:
#        Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 550068  P00128942       1    5           7                           2
# 550069  P00113442       1    3          17                           0
# 550070  P00288442       0    4           1                           4
# 550071  P00145342       0    4           1                           4
# 550072  P00053842       0    3           1                           1
#
#         Marital_Status  Product_Category_1  Product_Category_2  \
# 550068               1                   1                11.0
# 550069               0                   3                 5.0
# 550070               1                   5                14.0
# 550071               1                   4                 9.0
# 550072               0                   4                 5.0
#
#         Product_Category_3  Purchase  A  B  C
# 550068                16.0       NaN  0  1  0
# 550069                16.0       NaN  0  0  1
# ...

# %%
df_test.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# A                                  0
# B                                  0
# C                                  0
# dtype: int64

# %%
df_train= df[~df['Purchase'].isnull()]
df_train.head()
# Out:
#   Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                           2
# 1  P00248942       0    1          10                           2
# 2  P00087842       0    1          10                           2
# 3  P00085442       0    1          10                           2
# 4  P00285442       1    7          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# ...

# %%
df_train.isnull().sum()
# Out:
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# A                             0
# B                             0
# C                             0
# dtype: int64

# %%
X= df_train.drop('Purchase', axis=1)

# %%
Y= df_train['Purchase']

# %%
# splitting the data for training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %%
X_train.drop('Product_ID',axis=1,inplace=True)
X_test.drop('Product_ID',axis=1,inplace=True)

# %%
## feature Scaling: here we will scale all the datasets into some range, which will be easy to perform ML ops.
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
#NOW we can train our model

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
target = iris.target

# Select two features for demonstration purposes
selected_features = ['sepal length (cm)', 'sepal width (cm)']
subset_data = data[selected_features]

# Visualize the original data
plt.scatter(subset_data[selected_features[0]], subset_data[selected_features[1]], c=target, cmap='viridis')
plt.xlabel(selected_features[0])
plt.ylabel(selected_features[1])
plt.title("Original Data")
plt.show()

# %%
# Min-Max Scaling
min_max_scaler = MinMaxScaler()
scaled_data_min_max = min_max_scaler.fit_transform(subset_data)

# Visualize the Min-Max scaled data
plt.scatter(scaled_data_min_max[:, 0], scaled_data_min_max[:, 1], c=target, cmap='viridis')
plt.xlabel(selected_features[0] + ' (Min-Max Scaled)')
plt.ylabel(selected_features[1] + ' (Min-Max Scaled)')
plt.title("Min-Max Scaled Data")
plt.show()

# %%
# Standardization
standard_scaler = StandardScaler()
scaled_data_standard = standard_scaler.fit_transform(subset_data)

# Visualize the standardized data
plt.scatter(scaled_data_standard[:, 0], scaled_data_standard[:, 1], c=target, cmap='viridis')
plt.xlabel(selected_features[0] + ' (Standardized)')
plt.ylabel(selected_features[1] + ' (Standardized)')
plt.title("Standardized Data")
plt.show()
